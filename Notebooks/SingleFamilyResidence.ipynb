# %%
import pandas as pd
import numpy as np
import csv
import os
import io
import csv
import plotly.plotly as py
import plotly.figure_factory as ff

# %%
csv_path = os.path.join("Zip_Zhvi_SingleFamilyResidence2.csv")
sfr = pd.read_csv(csv_path)
sfr.head()
# Out:
#        City State              Metro CountyName   1996-04   1996-05   1996-06  \
# 0   Chicago    IL            Chicago       Cook  334200.0  335400.0  336500.0
# 1  McKinney    TX  Dallas-Fort Worth     Collin  235700.0  236900.0  236700.0
# 2      Katy    TX            Houston     Harris  210400.0  212200.0  212200.0
# 3   Chicago    IL            Chicago       Cook  498100.0  500900.0  503100.0
# 4   El Paso    TX            El Paso    El Paso   77300.0   77300.0   77300.0
#
#     1996-07   1996-08   1996-09   ...     2017-07  2017-08  2017-09  2017-10  \
# 0  337600.0  338500.0  339500.0   ...     1005500  1007500  1007800  1009600
# 1  235400.0  233300.0  230600.0   ...      308000   310000   312500   314100
# 2  210700.0  208300.0  205500.0   ...      321000   320600   320200   320400
# 3  504600.0  505500.0  505700.0   ...     1289800  1287700  1287400  1291500
# 4   77300.0   77400.0   77500.0   ...      119100   119400   120000   120300
#
# ...

# %%
kcmetrosfr1 = sfr.loc[sfr["Metro"] == "Kansas City"]
kcmetrosfr1
#attended_bootcamp = reduced_coders_pd.loc[reduced_coders_pd["AttendedBootcamp"] == "Yes"]
#attended_bootcamp.head()
# Out:
#                   City State        Metro   CountyName   1996-04   1996-05  \
# 91              Olathe    KS  Kansas City      Johnson  107200.0  107400.0
# 365             Olathe    KS  Kansas City      Johnson   96600.0   96700.0
# 943          Gladstone    MO  Kansas City         Clay   89800.0   90000.0
# 1520      Independence    MO  Kansas City      Jackson   79700.0   79900.0
# 1736           Raytown    MO  Kansas City      Jackson   73300.0   73600.0
# 2011     Overland Park    KS  Kansas City      Johnson   97000.0   97000.0
# 2129       Leavenworth    KS  Kansas City  Leavenworth   70000.0   69900.0
# 2466           Liberty    MO  Kansas City         Clay  108200.0  108600.0
# 2919       Kansas City    MO  Kansas City      Jackson   84500.0   84600.0
# 2953       Kansas City    MO  Kansas City      Jackson   87000.0   87400.0
# 3031      Blue Springs    MO  Kansas City      Jackson  104500.0  104800.0
# ...

# %%
kcmetro = kcmetrosfr1.loc[sfr["CountyName"].isin (["Jackson", "Johnson", "Wyandotte", "Clay", "Platte"])]
kcmetro
# Out:
#                   City State        Metro CountyName   1996-04   1996-05  \
# 91              Olathe    KS  Kansas City    Johnson  107200.0  107400.0
# 365             Olathe    KS  Kansas City    Johnson   96600.0   96700.0
# 943          Gladstone    MO  Kansas City       Clay   89800.0   90000.0
# 1520      Independence    MO  Kansas City    Jackson   79700.0   79900.0
# 1736           Raytown    MO  Kansas City    Jackson   73300.0   73600.0
# 2011     Overland Park    KS  Kansas City    Johnson   97000.0   97000.0
# 2466           Liberty    MO  Kansas City       Clay  108200.0  108600.0
# 2919       Kansas City    MO  Kansas City    Jackson   84500.0   84600.0
# 2953       Kansas City    MO  Kansas City    Jackson   87000.0   87400.0
# 3031      Blue Springs    MO  Kansas City    Jackson  104500.0  104800.0
# 3049     Overland Park    KS  Kansas City    Johnson  174400.0  174200.0
# 3359       Kansas City    MO  Kansas City    Jackson  125200.0  125600.0
# ...

# %%
kckmetro = kcmetro.loc[kcmetro["State"] == "KS"]
kckmetro
# Out:
#                   City State        Metro CountyName   1996-04   1996-05  \
# 91              Olathe    KS  Kansas City    Johnson  107200.0  107400.0
# 365             Olathe    KS  Kansas City    Johnson   96600.0   96700.0
# 2011     Overland Park    KS  Kansas City    Johnson   97000.0   97000.0
# 3049     Overland Park    KS  Kansas City    Johnson  174400.0  174200.0
# 3847            Lenexa    KS  Kansas City    Johnson  121800.0  122100.0
# 4121       Kansas City    KS  Kansas City  Wyandotte   38800.0   38800.0
# 4293       Kansas City    KS  Kansas City  Wyandotte   41300.0   41200.0
# 4566     Overland Park    KS  Kansas City    Johnson  146900.0  146900.0
# 4572   Prairie Village    KS  Kansas City    Johnson  105500.0  105400.0
# 4813           Shawnee    KS  Kansas City    Johnson  136500.0  136800.0
# 4814       Kansas City    KS  Kansas City  Wyandotte   85500.0   85600.0
# 4949     Overland Park    KS  Kansas City    Johnson   79900.0   80100.0
# ...

# %%
groupKS = kckmetro.groupby(["City"])
groupKS.mean().round(0)
# Create the GroupBy object based on the "Type 1" column
#pokemon_group = pokemon_type.groupby(["Type 1"])

# Calculate averages for combat stats using the .mean() method
#pokemon_group.mean()
# Out:
#                   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# City
# Bonner Springs    81600.0   82000.0   82500.0   83000.0   83500.0   84100.0
# De Soto           98800.0   99500.0  100300.0  101100.0  101900.0  102800.0
# Edgerton          76900.0   77300.0   77800.0   78200.0   78600.0   79100.0
# Gardner           87900.0   88100.0   88500.0   89100.0   89700.0   90600.0
# Kansas City       56957.0   57057.0   57157.0   57286.0   57400.0   57586.0
# Leawood          197825.0  198575.0  199475.0  200475.0  201575.0  202900.0
# Lenexa           140675.0  141850.0  143100.0  144300.0  145575.0  146800.0
# Mission           79500.0   79700.0   79900.0   80200.0   80600.0   81100.0
# Olathe           101900.0  102050.0  102350.0  102850.0  103600.0  104500.0
# Overland Park    140033.0  140244.0  140511.0  140822.0  141233.0  141767.0
# Prairie Village  105500.0  105400.0  105200.0  105200.0  105100.0  105300.0
# ...

# %%
groupKS1 = groupKS.mean().round(0)
groupKS1
# Out:
#                   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# City
# Bonner Springs    81600.0   82000.0   82500.0   83000.0   83500.0   84100.0
# De Soto           98800.0   99500.0  100300.0  101100.0  101900.0  102800.0
# Edgerton          76900.0   77300.0   77800.0   78200.0   78600.0   79100.0
# Gardner           87900.0   88100.0   88500.0   89100.0   89700.0   90600.0
# Kansas City       56957.0   57057.0   57157.0   57286.0   57400.0   57586.0
# Leawood          197825.0  198575.0  199475.0  200475.0  201575.0  202900.0
# Lenexa           140675.0  141850.0  143100.0  144300.0  145575.0  146800.0
# Mission           79500.0   79700.0   79900.0   80200.0   80600.0   81100.0
# Olathe           101900.0  102050.0  102350.0  102850.0  103600.0  104500.0
# Overland Park    140033.0  140244.0  140511.0  140822.0  141233.0  141767.0
# Prairie Village  105500.0  105400.0  105200.0  105200.0  105100.0  105300.0
# ...

# %%
groupKS1.reset_index(inplace=True)
groupKS1
# Out:
#                City   1996-04   1996-05   1996-06   1996-07   1996-08  \
# 0    Bonner Springs   81600.0   82000.0   82500.0   83000.0   83500.0
# 1           De Soto   98800.0   99500.0  100300.0  101100.0  101900.0
# 2          Edgerton   76900.0   77300.0   77800.0   78200.0   78600.0
# 3           Gardner   87900.0   88100.0   88500.0   89100.0   89700.0
# 4       Kansas City   56957.0   57057.0   57157.0   57286.0   57400.0
# 5           Leawood  197825.0  198575.0  199475.0  200475.0  201575.0
# 6            Lenexa  140675.0  141850.0  143100.0  144300.0  145575.0
# 7           Mission   79500.0   79700.0   79900.0   80200.0   80600.0
# 8            Olathe  101900.0  102050.0  102350.0  102850.0  103600.0
# 9     Overland Park  140033.0  140244.0  140511.0  140822.0  141233.0
# 10  Prairie Village  105500.0  105400.0  105200.0  105200.0  105100.0
# 11     Roeland Park  100000.0   99900.0   99900.0   99900.0  100000.0
# ...

# %%
kcmmetro = kcmetro.loc[kcmetro["State"] == "MO"]
kcmmetro
# Out:
#                     City State        Metro CountyName   1996-04   1996-05  \
# 943            Gladstone    MO  Kansas City       Clay   89800.0   90000.0
# 1520        Independence    MO  Kansas City    Jackson   79700.0   79900.0
# 1736             Raytown    MO  Kansas City    Jackson   73300.0   73600.0
# 2466             Liberty    MO  Kansas City       Clay  108200.0  108600.0
# 2919         Kansas City    MO  Kansas City    Jackson   84500.0   84600.0
# 2953         Kansas City    MO  Kansas City    Jackson   87000.0   87400.0
# 3031        Blue Springs    MO  Kansas City    Jackson  104500.0  104800.0
# 3359         Kansas City    MO  Kansas City    Jackson  125200.0  125600.0
# 3735         Kansas City    MO  Kansas City    Jackson   81300.0   81700.0
# 3823           Grandview    MO  Kansas City    Jackson   69400.0   69600.0
# 3861             Raytown    MO  Kansas City    Jackson   73000.0   73200.0
# ...

# %%
groupMO = kcmmetro.groupby(["City"])
groupMO.mean().round(0)
# Out:
#                     1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# City
# Blue Springs       100050.0  100250.0  100450.0  100750.0  100950.0  101300.0
# Buckner             71700.0   72000.0   72300.0   72500.0   72800.0   73100.0
# Dearborn            89300.0   89900.0   90400.0   91000.0   91600.0   92100.0
# Edgerton            88300.0   88700.0   89300.0   89800.0   90400.0   91000.0
# Excelsior Springs   75900.0   76200.0   76500.0   76900.0   77200.0   77700.0
# Gladstone           89800.0   90000.0   90100.0   90200.0   90300.0   90500.0
# Grain Valley       106500.0  106900.0  107400.0  107800.0  108200.0  108600.0
# Grandview           69400.0   69600.0   69700.0   69900.0   70100.0   70200.0
# Greenwood          112100.0  112600.0  113000.0  113500.0  114000.0  114500.0
# Holt               122900.0  123200.0  123400.0  123600.0  123800.0  124000.0
# Independence        76750.0   77000.0   77283.0   77500.0   77783.0   78000.0
# ...

# %%
groupMO1 = groupMO.mean().round(0)
groupMO1
# Out:
#                     1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# City
# Blue Springs       100050.0  100250.0  100450.0  100750.0  100950.0  101300.0
# Buckner             71700.0   72000.0   72300.0   72500.0   72800.0   73100.0
# Dearborn            89300.0   89900.0   90400.0   91000.0   91600.0   92100.0
# Edgerton            88300.0   88700.0   89300.0   89800.0   90400.0   91000.0
# Excelsior Springs   75900.0   76200.0   76500.0   76900.0   77200.0   77700.0
# Gladstone           89800.0   90000.0   90100.0   90200.0   90300.0   90500.0
# Grain Valley       106500.0  106900.0  107400.0  107800.0  108200.0  108600.0
# Grandview           69400.0   69600.0   69700.0   69900.0   70100.0   70200.0
# Greenwood          112100.0  112600.0  113000.0  113500.0  114000.0  114500.0
# Holt               122900.0  123200.0  123400.0  123600.0  123800.0  124000.0
# Independence        76750.0   77000.0   77283.0   77500.0   77783.0   78000.0
# ...

# %%
groupMO1.reset_index(inplace=True)
groupMO1.head()
# Out:
#                 City   1996-04   1996-05   1996-06   1996-07   1996-08  \
# 0       Blue Springs  100050.0  100250.0  100450.0  100750.0  100950.0
# 1            Buckner   71700.0   72000.0   72300.0   72500.0   72800.0
# 2           Dearborn   89300.0   89900.0   90400.0   91000.0   91600.0
# 3           Edgerton   88300.0   88700.0   89300.0   89800.0   90400.0
# 4  Excelsior Springs   75900.0   76200.0   76500.0   76900.0   77200.0
#
#     1996-09   1996-10   1996-11   1996-12    ...      2017-07   2017-08  \
# 0  101300.0  101600.0  101900.0  102250.0    ...     160950.0  162200.0
# 1   73100.0   73300.0   73600.0   73900.0    ...     109500.0  111600.0
# 2   92100.0   92700.0   93300.0   94000.0    ...     165200.0  167500.0
# 3   91000.0   91600.0   92300.0   93000.0    ...     179200.0  178600.0
# 4   77700.0   78100.0   78500.0   79000.0    ...     123800.0  123900.0
#
#     2017-09   2017-10   2017-11   2017-12   2018-01   2018-02   2018-03  \
# ...

# %%
file_name = os.path.join("MO_sfr_cg.csv")
groupMO1.to_csv(file_name, index=False)

# %%
file_name = os.path.join("KS_sfr_cg.csv")
groupKS1.to_csv(file_name, index=False)

# %%
import seaborn as sns
